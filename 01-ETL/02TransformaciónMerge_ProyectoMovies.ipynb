# %%
import pandas as pd
import numpy as np
import ast
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error # poner este como metrica
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/movies_dataset.csv')
data.head()
# Out:
# <ipython-input-54-b7cbb46dad4a>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/drive/MyDrive/movies_dataset.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/movies_dataset.csv')
print(data.shape)  # Verificar la cantidad de filas y columnas
print(data.columns)  # Obtener los nombres de las columnas
print(data.head())  # Mostrar las primeras filas del dataset
# Out:
# (45466, 24)
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# ...

# %%
# Desanidar la columna 'belongs_to_collection' y obtener el nombre
def extract_collection_name(x):
    try:
        collection = ast.literal_eval(x)
        return collection['name']
    except (ValueError, TypeError, KeyError):
        return np.nan

data['belongs_to_collection'] = data['belongs_to_collection'].apply(extract_collection_name)

# Verificar los resultados
print(data['belongs_to_collection'])
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 45461                               NaN
# 45462                               NaN
# 45463                               NaN
# 45464                               NaN
# 45465                               NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
#Desanidar la columna 'genres' y obtener el nombre
# Función de extracción de nombres de género
def extract_genre_names(x):
    try:
        genres = eval(x)
        genre_names = [genre['name'] for genre in genres]
        return ', '.join(genre_names)
    except:
        return ''

# Desanidar la columna 'genres' y obtener los nombres como una cadena
data['genres'] = data['genres'].apply(lambda x: extract_genre_names(x))

# Verificar los resultados
print(data['genres'])
# Out:
# 0         Animation, Comedy, Family
# 1        Adventure, Fantasy, Family
# 2                   Romance, Comedy
# 3            Comedy, Drama, Romance
# 4                            Comedy
#                     ...
# 45461                 Drama, Family
# 45462                         Drama
# 45463       Action, Drama, Thriller
# 45464
# 45465
# Name: genres, Length: 45466, dtype: object

# %%
#Desanidar la columna "production_companies" y obtener el nombre
# Función de extracción de nombres de production_companies:
import ast
import pandas as pd
import numpy as np

# Función de extracción de nombres de compañías de producción
def extract_company_names(x):
    try:
        companies = ast.literal_eval(x)
        company_names = [company['name'] for company in companies]
        return ', '.join(company_names)
    except:
        return ''

# Desanidar la columna 'production_companies' y obtener los nombres como una cadena
data['production_companies'] = data['production_companies'].apply(lambda x: extract_company_names(x))

# Verificar los resultados
print(data['production_companies'])
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures, Teitler Film, Interscope Com...
# 2                             Warner Bros., Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4               Sandollar Productions, Touchstone Pictures
#                                ...
# 45461
# 45462                                          Sine Olivia
# 45463                              American World Pictures
# 45464                                            Yermoliev
# 45465
# Name: production_companies, Length: 45466, dtype: object

# %%
#production_countries,spoken_languages 
#Desanidar la columna "production_countries" y obtener el nombre
import ast
import pandas as pd
import numpy as np

# Función de extracción de nombres de países de producción
def extract_country_names(x):
    try:
        countries = ast.literal_eval(x)
        country_names = [country['name'] for country in countries]
        return ', '.join(country_names)
    except:
        return ''

# Desanidar la columna 'production_countries' y obtener los nombres como una cadena
data['production_countries'] = data['production_countries'].apply(lambda x: extract_country_names(x))

# Verificar los resultados

print(data['production_countries'].head(10))
# Out:
# 0                    United States of America
# 1                    United States of America
# 2                    United States of America
# 3                    United States of America
# 4                    United States of America
# 5                    United States of America
# 6           Germany, United States of America
# 7                    United States of America
# 8                    United States of America
# 9    United Kingdom, United States of America
# Name: production_countries, dtype: object

# %%
#Desanidar la columna "spoken_languages " y obtener el nombre
import ast
import pandas as pd
import numpy as np

# Función de extracción de nombres de idiomas hablados
def extract_language_names(x):
    try:
        languages = ast.literal_eval(x)
        language_names = [language['name'] for language in languages]
        return ', '.join(language_names)
    except:
        return ''

# Desanidar la columna 'spoken_languages' y obtener los nombres como una cadena
data['spoken_languages'] = data['spoken_languages'].apply(lambda x: extract_language_names(x))

# Verificar los resultados
print(data['production_countries'].head(50))
# Out:
# 0                             United States of America
# 1                             United States of America
# 2                             United States of America
# 3                             United States of America
# 4                             United States of America
# 5                             United States of America
# 6                    Germany, United States of America
# 7                             United States of America
# 8                             United States of America
# 9             United Kingdom, United States of America
# 10                            United States of America
# 11                    France, United States of America
# 12                            United States of America
# 13                            United States of America
# 14    France, Germany, Italy, United States of America
# 15                    France, United States of America
# 16            United Kingdom, United States of America
# ...

# %%
data.head()
# Out:
#    adult           belongs_to_collection    budget  \
# 0  False            Toy Story Collection  30000000
# 1  False                             NaN  65000000
# 2  False       Grumpy Old Men Collection         0
# 3  False                             NaN  16000000
# 4  False  Father of the Bride Collection         0
#
#                        genres                              homepage     id  \
# 0   Animation, Comedy, Family  http://toystory.disney.com/toy-story    862
# 1  Adventure, Fantasy, Family                                   NaN   8844
# 2             Romance, Comedy                                   NaN  15602
# 3      Comedy, Drama, Romance                                   NaN  31357
# 4                      Comedy                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# ...

# %%
#Los valores nulos de los columnas " revenue y  budget"deben ser rellenados por el número 0.
# Rellenar los valores nulos en las columnas 'revenue' y 'budget' con 0
data['revenue'] = data['revenue'].fillna(0)
data['budget'] = data['budget'].fillna(0)

# Verificar los resultados
print(data[['revenue', 'budget']])
# Out:
#            revenue    budget
# 0      373554033.0  30000000
# 1      262797249.0  65000000
# 2              0.0         0
# 3       81452156.0  16000000
# 4       76578911.0         0
# ...            ...       ...
# 45461          0.0         0
# 45462          0.0         0
# 45463          0.0         0
# 45464          0.0         0
# 45465          0.0         0
#
# [45466 rows x 2 columns]

# %%
# Eliminar los valores nulos en la columna 'release_date'
data = data.dropna(subset=['release_date'])

# Verificar los resultados
print(data['release_date'])
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45460    1991-05-13
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45379, dtype: object

# %%
#La columna : "release_date", deberán tener el formato AAAA-mm-dd
import pandas as pd

# Convertir la columna 'release_date' a tipo datetime
data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')

# Formatear la columna 'release_date' en el formato AAAA-mm-dd
data['release_date'] = data['release_date'].dt.strftime('%Y-%m-%d')

# Verificar los resultados
print(data['release_date'])
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45460    1991-05-13
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45379, dtype: object
# <ipython-input-64-1df1ab688ee4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')
# <ipython-input-64-1df1ab688ee4>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#crear la columna release_year donde extraerán el año de la columna :"release_date"
import pandas as pd

# Convertir la columna 'release_date' a tipo datetime
data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')

# Extraer el año y crear la columna 'release_year'
data['release_year'] = data['release_date'].dt.year
data['release_year'] = data['release_year'].fillna(0).astype(int)

# Verificar los resultados
print(data['release_year'])
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45460    1991
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: release_year, Length: 45379, dtype: int64
# <ipython-input-65-05f974899f20>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')
# <ipython-input-65-05f974899f20>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#
# Eliminar las columnas no utilizadas
columns_to_drop = ['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage']
data = data.drop(columns=columns_to_drop)

# Verificar los resultados
print(data.head())
# Out:
#             belongs_to_collection    budget                      genres  \
# 0            Toy Story Collection  30000000   Animation, Comedy, Family
# 1                             NaN  65000000  Adventure, Fantasy, Family
# 2       Grumpy Old Men Collection         0             Romance, Comedy
# 3                             NaN  16000000      Comedy, Drama, Romance
# 4  Father of the Bride Collection         0                      Comedy
#
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
# ...

# %%
#Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget, 
#dividiendo estas dos últimas revenue / budget, cuando no hay datos disponibles para calcularlo, deberá tomar el valor 0
# Función para calcular el retorno de inversión

# Función para calcular el retorno de inversión
def calculate_return(row):
    revenue = row['revenue']
    budget = row['budget']
    if pd.notnull(revenue) and pd.notnull(budget):
        try:
            revenue = float(revenue)
            budget = float(budget)
            if budget != 0:
                return revenue / budget
            else:
                return 0
        except ValueError:
            return 0
    else:
        return 0

# Crear la columna 'return' con el retorno de inversión
data['return'] = data.apply(calculate_return, axis=1)

# Verificar los resultados
print(data['return'])
# Out:
# 0        12.451801
# 1         4.043035
# 2         0.000000
# 3         5.090760
# 4         0.000000
#            ...
# 45460     0.000000
# 45462     0.000000
# 45463     0.000000
# 45464     0.000000
# 45465     0.000000
# Name: return, Length: 45379, dtype: float64

# %%
data.head()
# Out:
#             belongs_to_collection    budget                      genres  \
# 0            Toy Story Collection  30000000   Animation, Comedy, Family
# 1                             NaN  65000000  Adventure, Fantasy, Family
# 2       Grumpy Old Men Collection         0             Romance, Comedy
# 3                             NaN  16000000      Comedy, Drama, Romance
# 4  Father of the Bride Collection         0                      Comedy
#
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
# ...

# %%
# Importando el Datasets Credits.
data2 = pd.read_csv('/content/drive/MyDrive/credits.csv')
data2.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
#desanidar la columna "cast", y quedarme solo con todos los name de cada fila: 
def extract_actor_names(row):
    try:
        cast = ast.literal_eval(row['cast'])
        actor_names = [actor['name'] for actor in cast]
        return ', '.join(actor_names)
    except:
        return ''

# %%
#Creando una nueva columna: "actor_name"
data2['ActorNames'] = data2.apply(extract_actor_names, axis=1)

# %%
print(data2['ActorNames'])
# Out:
# 0        Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1        Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2        Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3        Whitney Houston, Angela Bassett, Loretta Devin...
# 4        Steve Martin, Diane Keaton, Martin Short, Kimb...
#                                ...
# 45471            Leila Hatami, Kourosh Tahami, Elham Korda
# 45472    Angel Aquino, Perry Dizon, Hazel Orencio, Joel...
# 45473    Erika Eleniak, Adam Baldwin, Julie du Page, Ja...
# 45474    Iwan Mosschuchin, Nathalie Lissenko, Pavel Pav...
# 45475
# Name: ActorNames, Length: 45476, dtype: object

# %%
#desanidar la columna "crew", y quedarme solo con todos los name de los directores de cada fila:

import pandas as pd
import ast

# Función para extraer el nombre del director
def get_directors_names(crew_data):
    try:
        crew_data = ast.literal_eval(crew_data)
        director_names = [i['name'] for i in crew_data if i['job'] == 'Director']
        return ', '.join(director_names) if director_names else None
    except (ValueError, SyntaxError) as e:
        print(f'Error al procesar datos: {e}')
        return None

# Desanidar la columna "crew" y crear la columna "DirectorNames"
data2['DirectorNames'] = data2['crew'].apply(get_directors_names)

data2.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                           ActorNames    DirectorNames
# 0  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...    John Lasseter
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...     Joe Johnston
# 2  Walter Matthau, Jack Lemmon, Ann-Margret, Soph...    Howard Deutch
# ...

# %%
#eliminar la columna : cast	y crew de:data2 

# Eliminar las columnas 'cast' y 'crew'
data2 = data2.drop(['cast', 'crew'], axis=1)

# Mostrar las primeras filas del DataFrame actualizado
print(data2.head())
# Out:
#       id                                         ActorNames    DirectorNames
# 0    862  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...    John Lasseter
# 1   8844  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...     Joe Johnston
# 2  15602  Walter Matthau, Jack Lemmon, Ann-Margret, Soph...    Howard Deutch
# 3  31357  Whitney Houston, Angela Bassett, Loretta Devin...  Forest Whitaker
# 4  11862  Steve Martin, Diane Keaton, Martin Short, Kimb...    Charles Shyer

# %%
#Listando Update:
data2.head()
# Out:
#       id                                         ActorNames    DirectorNames
# 0    862  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...    John Lasseter
# 1   8844  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...     Joe Johnston
# 2  15602  Walter Matthau, Jack Lemmon, Ann-Margret, Soph...    Howard Deutch
# 3  31357  Whitney Houston, Angela Bassett, Loretta Devin...  Forest Whitaker
# 4  11862  Steve Martin, Diane Keaton, Martin Short, Kimb...    Charles Shyer

# %%
#Explorando los Datos:


# Verificar las columnas en ambos DataFrames
print("Columnas en data:")
print(data.columns)
print()
print("Columnas en data2:")
print(data2.columns)
# Out:
# Columnas en data:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'release_year', 'return'],
#       dtype='object')
#
# Columnas en data2:
# Index(['id', 'ActorNames', 'DirectorNames'], dtype='object')

# %%
#unir(MERGE) 2 data sets , por medio de la columna id de ambos
 #data = pd.read_csv('/content/drive/MyDrive/movies_dataset.csv') y data2 = pd.read_csv('/content/drive/MyDrive/credits.csv') 


import pandas as pd

# Asegurándonos de que 'id' sea del mismo tipo de dato en ambos dataframes
data['id'] = data['id'].astype(str)
data2['id'] = data2['id'].astype(str)

# Realizando el merge
merged_data = pd.merge(data, data2, on='id')

# %%
# Mostrar el DataFrame unido
print(merged_data)
# Out:
#                 belongs_to_collection    budget                      genres  \
# 0                Toy Story Collection  30000000   Animation, Comedy, Family
# 1                                 NaN  65000000  Adventure, Fantasy, Family
# 2           Grumpy Old Men Collection         0             Romance, Comedy
# 3                                 NaN  16000000      Comedy, Drama, Romance
# 4      Father of the Bride Collection         0                      Comedy
# ...                               ...       ...                         ...
# 45446                             NaN         0      Drama, Action, Romance
# 45447                             NaN         0                       Drama
# 45448                             NaN         0     Action, Drama, Thriller
# 45449                             NaN         0
# 45450                             NaN         0
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# ...

# %%
merged_data.head()
# Out:
#             belongs_to_collection    budget                      genres  \
# 0            Toy Story Collection  30000000   Animation, Comedy, Family
# 1                             NaN  65000000  Adventure, Fantasy, Family
# 2       Grumpy Old Men Collection         0             Romance, Comedy
# 3                             NaN  16000000      Comedy, Drama, Romance
# 4  Father of the Bride Collection         0                      Comedy
#
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
# ...

# %%
# Exportar el DataFrame fusionado a un archivo CSV
merged_data.to_csv('/content/drive/MyDrive/merged_data.csv', index=False)
